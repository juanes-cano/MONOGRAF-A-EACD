# %% [markdown]
# ### Instrucciones de ejecución para proyecto
#
# ##### Abrir con Google Colaboratory Notebook "01-MONOGRAFIA.ipynb" que se encuentra en el repositorio, ejecutar las celdas paso a paso.
#
# ###### Gracias
